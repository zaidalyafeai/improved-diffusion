# %%
# !ls
# Out:
#  CalliarGen			 datasets		       run.py
#  LICENSE			 first_batch		       scripts
#  README.md			 improved_diffusion	       setup.py
# 'Visualize test results.ipynb'	 improved_diffusion.egg-info   test.sh
#  calliargen			 logs
#  calliargenconfig.json		 logsconfig.json

# %%
from glob import glob
import matplotlib.pyplot as plt
from PIL import Image
import os
for img_name in [23, 48, 73, 98, 123, 148, 173, 198, 223, 248, 249]:
    im = Image.open(f"logs/generated_calliargen_model_50k_onefont_model150000/{img_name}.png")
    plt.imshow(im)
    plt.show()

# %%
# !cat first_batch/
# Out:
# 0000.png  0000_capt.txt  0001.txt	0002.png  0002_capt.txt  0003.txt
# 0000.txt  0001.png	 0001_capt.txt	0002.txt  0003.png	 0003_capt.txt

# %%
display.Image("logs/generated_model001000/123.png")

# %%
# !ls first_batch
# Out:
# 0000.png  0000_capt.txt  0001.txt	0002.png  0002_capt.txt  0003.txt
# 0000.txt  0001.png	 0001_capt.txt	0002.txt  0003.png	 0003_capt.txt

# %%
from glob import glob
import matplotlib.pyplot as plt
from PIL import Image
import os
for img_name in os.listdir("first_batch"):
        
    if img_name.endswith(".png"):
        txt = open(f"first_batch/{img_name[:-4]}.txt", "r").read()
        print(txt)
        im = Image.open(f"first_batch/{img_name}")
        plt.imshow(im)
        plt.show()
